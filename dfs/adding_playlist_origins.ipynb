# %%
# Importing libraries
import pandas as pd

# %%
all_playlists = [
'1970s.csv',
'1980s.csv',
'1990s.csv',
'2000s.csv',
'2010s.csv',
'2020s.csv',
'best_of-blues_jazz_soul.csv',
'best_of-blues.csv',
'best_of-classic.csv',
'best_of-country.csv',
'best_of_electronic.csv',
'best_of_folk.csv',
'best_of_hiphop.csv',
'best_of_jazz.csv',
'best_of_soul.csv',
'best_of_new_age.csv',
'best_of_reggae.csv',
'best_of_rock.csv',
'best_of_afrobeats.csv',
'best_of_britpop.csv',
'best_of_deep_house.csv',
'best_of_dancehall.csv',
'best_of_dreampop.csv',
'best_of_drill.csv',
'best_of_electro_swing.csv',
'best_of_eurodance.csv',
'best_of_grime.csv',
'best_of_house.csv',
'best_of_kpop.csv',
'best_of_latin.csv',
'best_of_melodic_death_metal.csv',
'best_of_metal.csv',
'best_of_neue_deutsche_welle.csv',
'best_of_reggaeton.csv',
'best_of_soundtrack1.csv',
'best_of_soundtrack2.csv',
'best_of_organic_house.csv',
'best_of_pop.csv',
'best_of_punk.csv',
'best_of_rap.csv',
'best_of_rnb.csv',
'best_of_ska.csv',
'best_of_synthwave.csv',
'best_of_trap.csv',
'best_of_trip_hop.csv',
'best_of_world.csv',
'2023_best_of.csv',
'2023_bravohits.csv',
'2023_deutschrap.csv',
'2023_house_techno.csv',
'2023_the_dome.csv',
'2023_tech_house.csv',
'2023_hiphop_mixtape.csv',
'handpicked_afterlife.csv',
'handpicked_berlin.csv',
'handpicked_be_svendsen.csv',
'handpicked_billie_eilish.csv',
'handpicked_bravo_hits.csv',
'handpicked_bremer_partymix.csv',
'handpicked_faber.csv',
'handpicked_gisbert.csv',
'handpicked_hungry_music.csv',
'handpicked_indie_melody.csv',
'handpicked_karaoke.csv',
'handpicked_manu_chao.csv',
'handpicked_modus_mio.csv',
'handpicked_money_boy.csv',
'handpicked_peter_fox_radio.csv',
'handpicked_peter_licht.csv',
'handpicked_slowdown_tuesday.csv',
'handpicked_sonne_mond_sterne.csv',
'handpicked_the_streets.csv',
'handpicked_worakls.csv'
]

# %%
len(all_playlists)
# Out:
# 73

# %%
for i in all_playlists:
    try:
        df = pd.read_csv(i)
        df['playlist'] = i
        df.to_csv(i, index=False)
    except:
        print('No success:', i)
        pass
    print(i, df.shape)
# Out:
# 1970s.csv (150, 19)
# 1980s.csv (72, 19)
# 1990s.csv (72, 19)
# 2000s.csv (73, 19)
# 2010s.csv (100, 19)
# 2020s.csv (57, 19)
# best_of-blues_jazz_soul.csv (22, 19)
# best_of-blues.csv (70, 19)
# best_of-classic.csv (83, 19)
# best_of-country.csv (100, 19)
# best_of_electronic.csv (100, 19)
# best_of_folk.csv (63, 19)
# best_of_hiphop.csv (100, 19)
# best_of_jazz.csv (20, 19)
# best_of_soul.csv (58, 19)
# best_of_new_age.csv (94, 19)
# best_of_reggae.csv (84, 19)
# best_of_rock.csv (295, 19)
# best_of_afrobeats.csv (187, 19)
# best_of_britpop.csv (50, 19)
# best_of_deep_house.csv (57, 19)
# best_of_dancehall.csv (104, 19)
# best_of_dreampop.csv (50, 19)
# best_of_drill.csv (100, 19)
# best_of_electro_swing.csv (151, 19)
# best_of_eurodance.csv (302, 19)
# best_of_grime.csv (330, 19)
# best_of_house.csv (88, 19)
# best_of_kpop.csv (340, 19)
# best_of_latin.csv (65, 19)
# best_of_melodic_death_metal.csv (130, 19)
# best_of_metal.csv (200, 19)
# best_of_neue_deutsche_welle.csv (50, 19)
# best_of_reggaeton.csv (100, 19)
# best_of_soundtrack1.csv (82, 19)
# best_of_soundtrack2.csv (58, 19)
# best_of_organic_house.csv (50, 19)
# best_of_pop.csv (180, 19)
# best_of_punk.csv (95, 19)
# best_of_rap.csv (331, 19)
# best_of_rnb.csv (209, 19)
# best_of_ska.csv (100, 19)
# best_of_synthwave.csv (31, 19)
# best_of_trap.csv (415, 19)
# best_of_trip_hop.csv (250, 19)
# best_of_world.csv (50, 19)
# 2023_best_of.csv (200, 19)
# 2023_bravohits.csv (57, 19)
# 2023_deutschrap.csv (94, 19)
# 2023_house_techno.csv (60, 19)
# 2023_the_dome.csv (60, 19)
# 2023_tech_house.csv (164, 19)
# 2023_hiphop_mixtape.csv (100, 19)
# handpicked_afterlife.csv (140, 19)
# handpicked_berlin.csv (400, 19)
# handpicked_be_svendsen.csv (32, 19)
# handpicked_billie_eilish.csv (60, 19)
# handpicked_bravo_hits.csv (519, 19)
# handpicked_bremer_partymix.csv (109, 19)
# handpicked_faber.csv (47, 19)
# handpicked_gisbert.csv (137, 19)
# handpicked_hungry_music.csv (39, 19)
# handpicked_indie_melody.csv (610, 19)
# handpicked_karaoke.csv (127, 19)
# handpicked_manu_chao.csv (23, 19)
# handpicked_modus_mio.csv (50, 19)
# handpicked_money_boy.csv (88, 19)
# handpicked_peter_fox_radio.csv (50, 19)
# handpicked_peter_licht.csv (50, 19)
# handpicked_slowdown_tuesday.csv (107, 19)
# handpicked_sonne_mond_sterne.csv (33, 19)
# handpicked_the_streets.csv (36, 19)
# handpicked_worakls.csv (48, 19)
